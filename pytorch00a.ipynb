# %% [markdown]
# <a href="https://colab.research.google.com/github/paradox-shivansh/Pytorch/blob/master/pytorch00a.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #Tensor Aggrigation (Min, Max, sum and etc)

# %%
import torch
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sb

# %% [markdown]
# Look how default datatype changes in the arange methord

# %%
x = torch.arange(0 , 100 , 1)
x.dtype
# Out:
# torch.int64

# %%
y = torch.arange(0 , 100 , 0.5)
y.dtype
# Out:
# torch.float32

# %%
torch.max(x) , torch.min(x)
# Out:
# (tensor(99), tensor(0))

# %%
torch.mean(x.float())
# Out:
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# /tmp/ipython-input-387790371.py in <cell line: 0>()
# ----> 1 torch.mean(x)
#
# RuntimeError: mean(): could not infer output dtype. Input dtype must be either a floating point or complex dtype. Got: Long

# %%
torch.mean(x.type(torch.float32)) , x.type(torch.float32).mean()
# Out:
# (tensor(49.5000), tensor(49.5000))

# %% [markdown]
# ##Positional MinMax

# %%
x.argmin() , x.argmax()
# Out:
# (tensor(0), tensor(99))
